# %%
from pymongo import MongoClient


client = MongoClient("mongodb://localhost:27017/")
db = client["demomongo1"]
#clname=input("enter the collection name you want to create")
collection = db["myproject"]
def totalamtsum():
    pipeline = [
        {"$group": {"_id": None, "total_sum": {"$sum": "$total_amount"}}}
    ]
    result = collection.aggregate(pipeline)
    for doc in result:
        print("Total Sum:", doc["total_sum"])

def mongoupdate():
            mngu=int(input("enter 1 to update based on name \n enter 2  to update based on city \n enter 3 to go back to mongo action"))
            if mngu==1:
                upd1=int(input("enter 1 to update based on names \n enter 2 add new field based on names \n 3 to updatemany on name field "))
                if upd1==1:
                    ginti=0
                    for document5 in collection.find({}, {"name": 1, "_id": 0}):
                        nmvar=document5["name"]
                        nm1={"name":nmvar}
                        print(" update will be done where name is:",nmvar)
                        updnm1=int(input("enter 1 to update the name field here \n 2 to update city field \n enter 3 to perform no action amd skip next document \n 4 to end the current order"))
                        if updnm1==1:
                            new_nm=input("enter the new name you want to replace")
                            operationupd={"$set":{"name": new_nm}}
                            result1= collection.update_one(nm1,operationupd)
                            print("updated name successfully")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                            
                                
                        elif updnm1==2:
                            new_addrs=input("enter the new city you want to replace")
                            operationupd={"$set":{"city": new_addrs}}
                            result1= collection.update_one(nm1,operationupd)
                            print("updated city successfully")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif updnm1==3:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif updnm1==4:
                            print("moved out to mongoupdate")
                            break
                    
                    mongoupdate()    
                            
                            
                elif upd1==2:
                    ginti=0
                    for document5 in collection.find({}, {"name": 1, "_id": 0}):
                        nmvar=document5["name"]
                        nm1={"name":nmvar}
                        chc1=int(input("enter 1 to add new field \n 2 to skip the document \n 3 to move out to mongo update" ))
                        if chc1==1:
                            print(" field will be added where name is:",nmvar)
                            new_fld=input("enter the  name of new field you want to create")
                            new_value=input("enter the value of new value you want to create")
                            newfield_operation = {"$set": {new_fld: new_value}}
                            result2 = collection.update_one(nm1, newfield_operation)
                            print("new field added sucessfuly")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                            
                            
                        elif chc1==2:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif chc1==3:
                            print("moved out to mongoupdate")
                            break
                            
                            
                    mongoupdate()
                elif upd1==3:
                    
                    for document5 in collection.find({}, {"name": 1, "_id": 0}):
                        
                        print(document5["name"])
                    ulm1=input("from above output select the name and 'enter it here for performing update many operation':")
                    new_name=input("enter the new name you want to replace")
                    update_many_operation={"$set":{"name": new_name}}
                    result1= collection.update_many({"name":ulm1},update_many_operation)
                    print("all documents updated where name was:",ulm1)
                    mongoupdate()
                
                
            elif mngu==2:
                
                upd1=int(input("enter 1 to update based on names \n enter 2 add new field based on names \n 3 to updatemany on city field "))
                if upd1==1:
                    ginti=0
                    for document5 in collection.find({}, {"city": 1, "_id": 0}):
                        advar=document5["city"]
                        ad1={"city":advar}
                        print(" update will be done where city is:",advar)
                        updnm1=int(input("enter 1 to update the name field here \n 2 to update city field \n enter 3 to perform no action and skip next document \n 4 to move to mongoupdate"))
                        if updnm1==1:
                            new_nm=input("enter the new name you want to replace")
                            operationupd={"$set":{"name": new_nm}}
                            result1= collection.update_one(ad1,operationupd)
                            print("updated name successfully")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif updnm1==2:
                            
                            new_addrs=input("enter the new city you want to replace")
                            operationupd={"$set":{"city": new_addrs}}
                            result1= collection.update_one(ad1,operationupd)
                            print("updated city successfully")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif updnm1==3:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif updnm1==4:
                            print("moved out to mongoupdate")
                            break
                            
                            
                    mongoupdate()
                elif upd1==2:
                    ginti=0
                    for document5 in collection.find({}, {"city": 1, "_id": 0}):
                        advar=document5["city"]
                        ad1={"city":advar}
                        chc1=int(input("enter 1 to add new field \n 2 to skip the document \n 3 to move out to mongo update" ))
                        if chc1==1:
                            print(" field will be added where city is:",advar)
                            new_fld=input("enter the  name of new field you want to create")
                            new_value=input("enter the value of new value you want to create")
                            newfield_operation = {"$set": {new_fld: new_value}}
                            result2 = collection.update_one(advar, newfield_operation)
                            print("new field added sucessfuly")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                            
                            
                        elif chc1==2:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif chc1==3:
                            print("moved out to mongoupdate")
                            
                            break
                            
                    mongoupdate()
                
                elif upd1==3:
                    
                    for document5 in collection.find({}, {"adddress": 1, "_id": 0}):
                        
                        print(document5["city"])
                    alm1=input("from above output select the city and 'enter it here for performing update many operation':")
                    new_city=input("enter the new city you want to replace")
                    update_many_operation ={"$set":{"city": new_city}}
                    result1= collection.update_many({"city":alm1},update_many_operation)
                    print("all documents updated where name was:",alm1)
                    mongoupdate()
                        
                
                
            elif mngu==3:
                print("going back to mongo action")
                mongoaction()
def mongodelete():
            mngu=int(input("enter 1 to delete based on name \n enter 2  to delete based on city \n enter 3 to go back to mongo action"))
            if mngu==1:
                upd1=int(input("enter 1 to delete based on names \n enter 2 to delete many document based on names"))
                if upd1==1:
                    
                    ginti=0
                    for document6 in collection.find({}, {"name": 1, "_id": 0}):
                        nmvar=document6["name"]
                        nm1={"name":nmvar}
                        cnfdel=int(input("enter 1 to confirm deletion \n 2 to skip the document \n 3 to  move to mongodelete"))
                        if cnfdel==1:
                            print(" delete will be done where name is:",nmvar)
                            result1= collection.delete_one(nm1)
                            print( "document deleted where name is: ",nmvar)
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif cnfdel==2:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif cnfdel==3:
                            print("moved out to mongodelete")
                            break
                    mongodelete()
                elif upd1==2:
                    for document6 in collection.find({}, {"name": 1, "_id": 0}):
                        print(document6["name"])
                    dlm1=input("from above output select the name and 'enter it here for performing delete many operation':")
                    result1= collection.delete_many({"name":dlm1})
                    print("all documents deleted where name was:",dlm1)
                    mongodelete()
            elif mngu==2:
                upd1=int(input("enter 1 to delete based on city \n enter 2 to delete many document based on city"))
                if upd1==1:
                    
                    ginti=0
                    for document6 in collection.find({}, {"city": 1, "_id": 0}):
                        addres=document6["city"]
                        ares1={"city":addres}
                        cnfdel=int(input("enter 1 to confirm deletion \n 2 to skip the document \n 3 to  move to mongodelete"))
                        if cnfdel==1:
                            print(" delete will be done where city is:",)
                            result1= collection.delete_one(ares1)
                            print( "document deleted where name is: ",ares1)
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif chc1==2:
                            print("skipped to next document----------")
                            ginti=ginti+1
                            print("moved out of document ",ginti)
                        elif cnfdel==3:
                            print("moved out to mongodelete")
                            break
                        
                    mongodelete()
                               
                            
                            
                elif upd1==2:
                    
                    for document6 in collection.find({}, {"city": 1, "_id": 0}):
                        
                        print(document6["city"])
                    dla1=input("from above output select the city and 'enter it here for performing delete many operation':")
                    result1= collection.delete_many({"city":dla1})
                    print("all documents deleted where city was:",dla1)
                    mongodelete()
                        
                        
                        
                
                
            elif mngu==3:
                print("going back to mongo action")
                mongoaction()
def mongoagg():
            agg1=int(input("enter 1 to perform group action \n 3 to back to mongo action"))
            if agg1==1:
                
                agt1=int(input("enter 1 to group based on city \n  enter 2 to group based on name \n 3 to group based on total amount "))
                if agt1==1:
                    
                    adrs1=input("enter city on basis which you want to make group ")
                    
                    result7=collection.aggregate([{"$match": {"city": adrs1}},{"$group": {"_id": "$name", "count": {"$sum": 1}}}])
                    for document4 in result7:
                        print(f"Name: {document4['_id']}")
                    mongoagg()
                elif agt1==2:
                    nm1=input("enter name on basis which you want to make group ")
                    
                    result7=collection.aggregate([{"$match": {"name": nm1}},{"$group": {"_id": "$name", "count": {"$sum": 1}}}])
                    for document4 in result7:
                        
                        print(f"Name: {document4['_id']}")
                    mongoagg()
                elif agt1==3:
                    tamnt=int(input("enter the total_amount on basis of which you want to make group"))
                    
                    result7=collection.aggregate([{"$match": {"total_amount": tamnt}},{"$group": {"_id": "$name", "count": {"$sum": 1}}}])
                    for document4 in result7:
                        print(f"Name: {document4['_id']}")
                    mongoagg()
                    
            elif agg1==3:
                print("going back to mongo action")
                mongoaction()
def mongogtandlt():
            
            mngv=int(input("enter 1 for greater than action  \n enter 2 for less than \n enter 3 for custom greater than and less than \n enter 4 for max and min amount  \n enter 5 to get to mongoaction "))
            
            if mngv==1:
                
                gt1=int(input("enter the value you want output to be greater than from total amount"))
                fltr_doc = collection.find({"total_amount": {"$gt": gt1}}, {"name": 1, "total_amount": 1, "_id": 0})
                for document2 in fltr_doc:
                    print(f"Name: {document2['name']}, Total Amount: {document2['total_amount']}")
                mongogtandlt()
                
            elif mngv==2:
                lt1=int(input("enter the value you want output to be less than from total amount"))
                fltr_doc = collection.find({"total_amount": {"$lt": lt1}}, {"name": 1, "total_amount": 1, "_id": 0})
                for document2 in fltr_doc:
                    print(f"Name: {document2['name']}, Total Amount: {document2['total_amount']}")
                mongogtandlt()
                        
            elif mngv==3:
                gt2=int(input("enter the value you want output to be greater than from total amount"))
                lt2=int(input("enter the value you want output to be less than from total amount"))
                fltr_doc = collection.find({"total_amount": {"$gt": gt2, "$lt": lt2}}, {"name": 1, "total_amount": 1, "_id": 0})
                for document2 in fltr_doc:
                    print(f"Name: {document2['name']}, Total Amount: {document2['total_amount']}")
                mongogtandlt()
                    
            elif mngv==4:
                mgv2=int(input("enter 1 for max from total amount \n enter 2 for min total amount"))
                if mgv2==1:
                    max_documents = collection.find().sort("total_amount", -1).limit(1)
                    for document3 in max_documents:
                        print(f"Name: {document3['name']}, Price: {document3['total_amount']}, Order: {document3['orders']}, city: {document3['city']}")
                    mongogtandlt()
                elif mgv2==2:
                    min_documents = collection.find().sort("total_amount", 1).limit(1)
                    for document3 in min_documents:
                        print(f"Name: {document3['name']}, Price: {document3['total_amount']}, Order: {document3['orders']}, city: {document3['city']}")
                    mongogtandlt()
                    
            elif mngv==5:
                
                print("monving out mongo greater than less than")
                mongoaction()
def mongosort():
            mngs1=int(input("enter 1 to sort desecnding \n 2 to ascending \n 3 to go back to previous selection " ))
            if mngs1==1:
                mngs1_1=int(input("enter 1 to sort based on names \n 2 based on total amount \n 3 based on city"))
                if mngs1_1==1:
                    srtd_docs= collection.find().sort("name", -1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()
                elif mngs1_1==2:
                    srtd_docs= collection.find().sort("total_amount", -1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()
                elif  mngs1_1==3:
                    srtd_docs= collection.find().sort("city", -1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()
            elif mngs1==2:
                mngs1_2=int(input("enter 1 to sort based on names \n 2 based on total amount \n 3 based on city"))
                if mngs1_2==1:
                    srtd_docs= collection.find().sort("name", 1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()
                elif mngs1_2==2:
                    srtd_docs= collection.find().sort("total_amount", 1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()
                elif mngs1_2==3:
                    srtd_docs= collection.find().sort("city", 1)
                    for document1 in srtd_docs:
                        print(f"Name: {document1['name']}, Price: {document1['total_amount']}, Order: {document1['orders']}, city: {document1['city']}")
                    mongosort()       
            elif mngs1==3:
                print("you will be moved out of mongo sort")
                mongoaction()
def mongofind():
            mng1=int(input("enter 1 to disply all record \n 2 to display records in single fields \n 3 to go back to selection to find group and sort"))
            if mng1==1:   
                for document in collection.find():
                    print(document)
                mongofind()
            elif mng1==2:
                mng2=int(input("enter 1 to display the name field \n 2 to  display name and   city field \n 3 to display name and  number field \n 4 to diaplay name and order field \n 5 to display name and price"))
                if mng2==1:
                    for document in collection.find({}, {"name": 1, "_id": 0}):
                        print(document["name"])
                    
                    mongofind()
                elif mng2==2:
                    for document in collection.find({}, {"name": 1, "city": 1, "_id": 0}):
                        print(f"Name: {document['name']}, city: {document['city']}")
                    mongofind()
                elif mng2==3:
                    for document in collection.find({}, {"name": 1, "number": 1, "_id": 0}):
                        print(f"Name: {document['name']}, Number: {document['number']}")
                    mongofind()
                elif mng2==4:
                    for document in collection.find({}, {"name": 1, "orders": 1, "_id": 0}):
                        print(f"Name: {document['name']}, Order: {document['orders']}")
                    mongofind()
                elif mng2==5:
                    for document in collection.find({}, {"name": 1, "total_amount": 1, "_id": 0}):
                        print(f"Name: {document['name']}, Price: {document['total_amount']}")
                    mongofind()
            elif mng1==3:
                print("you will be moved out of mongo find")
                mongoaction()

def newwf():
    intro = int(input("Enter 1 to use website \n  2 to end the program: "))
    if intro== 2:
        endof()
    elif intro == 1:
        print("Hello! Welcome to the online food ordering system")
        print("Please enter your details")
        x = str(input("Enter your name customer: "))
        y = str(input("Enter your city: "))
        y1=str(input("Enter your state: "))
        z = int(input("Enter your number: "))
        def createdocument():
            doc = {"name": x, "city": y, "state":y1, "number": z}
            collection.insert_one(doc)
            print("document created")
        j = str(input("Enter 'yes' if you want to create a document: "))
        if j == "yes":
            createdocument()

        s_1 = []
        total_amount=0
        x1 = int(input("Enter 1 to order food: "))
        def userdetails():
            documentdt=collection.find({'name': x})
            for doc in documentdt:
                
                print(doc)
            print(" these are your details")
            
        print("Customer please start ordering food")                   
        while x1 == 1:
            x_1 = int(input("Enter 11 to order Indian food \n  Enter 22 to view your detail \n  Enter 33  will close the window and new user will be there : "))
            match x_1:
                case 11:
                    c_1 = int(input("Enter 0 to move out of Indian food order \n 11 to continue: "))
                    while c_1 != 0:
                        l1 = ["Biryani", "Butter Chicken", "Tandoori Chicken", "Paneer Tikka", "Masala Dosa", "Palak Paneer", "Chole Bhature"]
                        price=[90,120,120,100,50,80,60]
                        e_1 = int(input("Enter 1 to order Biryani \n Enter 2 to order Butter Chicken \n Enter 3 to order Tandoori Chicken \n Enter 4 to order Paneer Tikka \n Enter 5 to order Masala Dosa \n Enter 6 to order Palak Paneer \n Enter 7 to order Chole Bhature: "))
                        match e_1:
                            case 1:
                                s_1.append(l1[0])
                                
                                total_amount=+price[0]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[0]},"$inc": {"total_amount": price[0]}})  # Add the order to the document's orders array
                                print(f"{l1[0]} added to your order.")
                                break
                            case 2:
                                s_1.append(l1[1])
                                
                                total_amount=+price[1]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[1]},"$inc": {"total_amount": price[1]}})  # Add the order to the document's orders array
                                print(f"{l1[1]} added to your order.")
                                break
                            case 3:
                                s_1.append(l1[2])
                                
                                total_amount=+price[2]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[2]},"$inc": {"total_amount": price[2]}})  # Add the order to the document's orders array
                                print(f"{l1[2]} added to your order.")
                                break
                            case 4:
                                s_1.append(l1[3])
                                
                                total_amount=+price[3]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[3]},"$inc": {"total_amount": price[3]}})
                                print(f"{l1[3]} added to your order.")
                                break
                            case 5:
                                s_1.append(l1[4])
                                
                                total_amount=+price[4]
                                collection.update_one({"name": x},{"$push": {"orders":l1[4]},"$inc": {"total_amount": price[4]}})
                                print(f"{l1[4]} added to your order.")
                                break
                            case 6:
                                s_1.append(l1[5])
                                
                                total_amount=+price[5]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[5]},"$inc": {"total_amount": price[5]}})
                                print(f"{l1[5]} added to your order.")
                                break
                            case 7:
                                s_1.append(l1[6])
                                
                                total_amount=+price[6]
                                collection.update_one({"name": x}, {"$push": {"orders":l1[6]},"$inc": {"total_amount": price[6]}})
                                print(f"{l1[6]} added to your order.")
                    
                                break
                        
                case 22:
                    userdetails()
                    break
                case 33:
                    roles()
                    break        
        
        
                
                        
                    
    


def admin():
    count=collection.count_documents({})
    if count==0:
        print("document is empty")
    elif count>0:
        nuk1=int(input("enter 1 for mongodb action"))
        if nuk1==1:
            
            mongoaction()
        else:
            print(" wrong value entered")
        
        
            
            

def mongoaction():
            print("admin is in control")
            act1=int(input("Enter 1 to perfor find operation \n Enter 2 to perfom sort operation \n Enter 3 to perform aggregate operation \n Enter 4 for greater than less than operation \n Enter 5 to perform update operation \n Enter 6 to perform delete operation \n Enter 7 to get toamount sum  \n Enter 8 to END the PROGRAM"))
            match act1:
                  case 1:
                      mongofind()
                  case 2:
                      mongosort()
                  case 3:
                      mongoagg()
                  case 4:
                      mongogtandlt()
                  case 5:
                      mongoupdate()
                  case 6:
                      mongodelete()
                  case 7:
                      totalamtsum()
                  case 8:
                      endof()
                                      
                                                
        
def endof():
    print("program ended")

def roles():
    mode1=int(input("enter 1 to if you are admin \n enter 2 if you are user \n 3 to end program"))
    match mode1:
        case 1:
            password=input("enter the admin password")
            if password=="123":
                admin()
            else:
                print("you are denied admin entry \nyour password is wrong")
        

    
        case 2:
            nq=input("enter yes to start  the website as user")
            if nq=="yes":
                newwf()
            else:
                print("you gave wrong entry")
roles()
